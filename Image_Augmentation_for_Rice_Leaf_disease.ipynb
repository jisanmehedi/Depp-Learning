# %% [markdown]
# # Image Augmentation

# %%
# !pip install sk
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py install for sk: started
#   Running setup.py install for sk: finished with status 'done'
# ...
#   DEPRECATION: sk is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: C:\Users\mehed\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install scipy
# Out:
# ...
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
# ...

# %%
pip install scikit-image

# %% [markdown]
# # Import necessary Libraries

# %%
import random
from scipy import ndarray
import skimage as sk
from skimage import transform
from skimage import util
import os
from skimage import io
from skimage import img_as_ubyte
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# i:\Research\Rice leaf disease\Original\Image_Augmentation_for_Rice_Leaf_disease.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/i%3A/Research/Rice%20leaf%20disease/Original/Image_Augmentation_for_Rice_Leaf_disease.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import random
# ----> <a href='vscode-notebook-cell:/i%3A/Research/Rice%20leaf%20disease/Original/Image_Augmentation_for_Rice_Leaf_disease.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> from scipy import ndarray
#       <a href='vscode-notebook-cell:/i%3A/Research/Rice%20leaf%20disease/Original/Image_Augmentation_for_Rice_Leaf_disease.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> import skimage as sk
#       <a href='vscode-notebook-cell:/i%3A/Research/Rice%20leaf%20disease/Original/Image_Augmentation_for_Rice_Leaf_disease.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> from skimage import transform
#
# ...

# %% [markdown]
# # Define Augmentation Methods

# %%
def random_rotation(image_array: ndarray):
    # pick a random degree of rotation between 25% on the left and 25% on the right
    random_degree = random.uniform(-25, 25)
    return sk.transform.rotate(image_array, random_degree)

def random_noise(image_array: ndarray):
    # add random noise to the image
    return sk.util.random_noise(image_array)

def horizontal_flip(image_array: ndarray):
    # horizontal flip doesn't need skimage, it's easy as flipping the image array of pixels !
    return image_array[:, ::-1]

# %% [markdown]
# # Augmentation

# %%
# our folder path containing some images
# folder_path = '/content/drive/MyDrive/COVID-META/STAR Work/COVID-19/Augmented'
folder_path = 'C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight'
# the number of file to generate
num_files_desired = 288

i=1
# loop on all files of the folder and build a list of files paths
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

num_generated_files = 0
while num_generated_files <= num_files_desired:

    # random image from the folder
    image_path = random.choice(images)
    # read image as an two dimensional array of pixels
    print(image_path)
    image_to_transform = sk.io.imread(image_path)
    available_transformations = {
    'rotate': random_rotation,
    'noise': random_noise,
    'horizontal_flip': horizontal_flip
    }

    # random num of transformations to apply
    num_transformations_to_apply = random.randint(1, len(available_transformations))

    num_transformations = 0
    transformed_image = None
    while num_transformations <= num_transformations_to_apply:
        # choose a random transformation to apply for a single image
        key = random.choice(list(available_transformations))
        transformed_image = available_transformations[key](image_to_transform)
        num_transformations += 1
        i=i+1
        nflpath='C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight/a'
        # define a name for our new file
        new_file_path = '%s/augmented_image_%s.jpg' %(nflpath, i)
        print(new_file_path)

        # Check and normalize data type before saving
        if transformed_image.dtype != 'uint8':
          transformed_image = img_as_ubyte(transformed_image)

        # write image to the disk
        sk.io.imsave(new_file_path, transformed_image)
    num_generated_files+=1
# Out:
# C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight\Sheath_blight P(171).jpg
# C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight/a/augmented_image_2.jpg
# C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight/a/augmented_image_3.jpg
# C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight\Sheath_blight P(129).jpg
# C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight/a/augmented_image_4.jpg
# C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight/a/augmented_image_5.jpg
# C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight/a/augmented_image_6.jpg
# C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight/a/augmented_image_7.jpg
# C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight\Sheath_Blight (48).jpg
# C:/Users/MEHEDI HASAN/Neural Network/Rice leaf disease/Sheath Blight/a/augmented_image_8.jpg
# ...
